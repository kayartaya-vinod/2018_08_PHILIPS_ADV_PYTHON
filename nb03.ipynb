# %%
import pandas as pd

# %%
data = pd.read_csv('./resources/drinks.csv')

# %%
data.country.sort_values(ascending=False)
# Out:
# 192                Zimbabwe
# 191                  Zambia
# 190                   Yemen
# 189                 Vietnam
# 188               Venezuela
# 187                 Vanuatu
# 186              Uzbekistan
# 185                 Uruguay
# 182          United Kingdom
# 181    United Arab Emirates
# 180                 Ukraine
# 179                  Uganda
# 184                     USA
# 178                  Tuvalu
# 177            Turkmenistan
# 176                  Turkey
# 175                 Tunisia
# 174       Trinidad & Tobago
# 173                   Tonga
# 172                    Togo
# 171             Timor-Leste
# 169                Thailand
# 183                Tanzania
# 168              Tajikistan
# 167                   Syria
# 166             Switzerland
# 165                  Sweden
# 164               Swaziland
# 163                Suriname
# 162                   Sudan
#                ...
# 30                 Cambodia
# 29               Cabo Verde
# ...

# %%
data.sort_values(by=['beer_servings', 'country'], ascending=[True, False])
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 158             Somalia              0                0              0
# 149        Saudi Arabia              0                5              0
# 147          San Marino              0                0              0
# 128            Pakistan              0                0              0
# 46          North Korea              0                0              0
# 111              Monaco              0                0              0
# 107          Mauritania              0                0              0
# 106    Marshall Islands              0                0              0
# 103            Maldives              0                0              0
# 97                Libya              0                0              0
# 90               Kuwait              0                0              0
# 79                 Iran              0                0              0
# ...

# %%
data.loc[data.country.str.upper().str.startswith('IN')]
# Out:
#       country  beer_servings  spirit_servings  wine_servings  \
# 77      India              9              114              0
# 78  Indonesia              5                1              0
#
#     total_litres_of_pure_alcohol continent
# 77                           2.2        AS
# 78                           0.1        AS

# %%
data.groupby('continent').beer_servings.describe()
# Out:
#            count        mean        std   min     25%    50%     75%    max
# continent
# AF          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS          44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# OC          16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA          12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0

# %%
data.groupby('continent').mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
data.groupby('continent').beer_servings.agg(['min', 'max', 'count', 'mean'])
# Out:
#            min  max  count        mean
# continent
# AF           0  376     53   61.471698
# AS           0  247     44   37.045455
# EU           0  361     45  193.777778
# OC           0  306     16   89.687500
# SA          93  333     12  175.083333

# %%
cars1 = pd.read_csv('resources/cars1.csv')
cars2 = pd.read_csv('resources/cars2.csv')

# %%
str(cars1.shape) + ', '  + str(cars2.shape)
# Out:
# '(198, 14), (200, 9)'

# %%
cars1 = cars1.loc[:, :'car']

# %%
cars = cars1.append(cars2)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
del cars['origin']

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#                          car
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %% [markdown]
# ### while adding or removing new series, the dot notation does not work
# #### del cars.no_of_users does not work

# %%
del cars['no_of_users']
cars['code'] = cars.car.str[:3]

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#                          car code
# 0  chevrolet chevelle malibu  che
# 1          buick skylark 320  bui
# 2         plymouth satellite  ply
# 3              amc rebel sst  amc
# 4                ford torino  for
